# %% [markdown]
# ## Matched Molecular Series
# ### Introduction
#
# This notebook implements matched molecular series as described in these papers.
#
# Wawer, Mathias, and Jürgen Bajorath. "Local structural changes, global data views: graphical substructure− activity relationship trailing." Journal of Medicinal Chemistry **54** (2011): 2944-2951. https://doi.org/10.1021/jm200026b
#
# O’Boyle, Noel M., Jonas Boström, Roger A. Sayle, and Adrian Gill. "Using matched molecular series as a predictive tool to optimize biological activity." *Journal of Medicinal Chemistry*, **57** (2014): 2704-2713. [https://doi.org/10.1021/jm500022q](https://doi.org/10.1021/jm500022q)

# %% [markdown]
# ### Setup
# Check to see if we're running in Google Colab

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

# %% [markdown]
# Install the necessary Python packages

# %%
# %%capture
if IN_COLAB:
    # !pip install pandas requests rdkit useful_rdkit_utils mols2grid

# %% [markdown]
# Download the scaffold_finder library from GitHub.

# %%
if IN_COLAB:
    import requests
    lib_file = requests.get("https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/sar_analysis/scaffold_finder.py")
    ofs = open("scaffold_finder.py","w")
    print(lib_file.text,file=ofs)
    ofs.close()

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem.rdMMPA import FragmentMol
from rdkit.Chem.rdDepictor import Compute2DCoords
from scaffold_finder import cleanup_fragment
from operator import itemgetter
import mols2grid
from rdkit.Chem.TemplateAlign import AlignMolToTemplate2D

# %% [markdown]
# Useful utility functions

# %%
def sort_fragments(mol):
    """
    Transform a molecule with multiple fragments into a list of molecules that is sorted by number of atoms
    from largest to smallest
    """
    frag_list = list(Chem.GetMolFrags(mol, asMols=True))
    frag_num_atoms_list = [(x.GetNumAtoms(), x) for x in frag_list]
    frag_num_atoms_list.sort(key=itemgetter(0), reverse=True)
    return [x[1] for x in frag_num_atoms_list]

# %% [markdown]
# ### Read Input
# Read the input data

# %%
infile_url = "../data/CHEMBL208.smi"
chembl208_df = pd.read_csv(infile_url,names=["SMILES","Name","pIC50"])

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
chembl208_df['mol'] = chembl208_df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# ### Generate Scaffold-Substituent Pairs
# Iterate over the molecules in the dataframe and transform to scaffold, substituent pairs

# %%
row_list = []
for smiles, name, pIC50, mol in chembl208_df.values:
    frag_list = FragmentMol(mol,maxCuts=1)
    for _,frag_mol in frag_list:
        pair_list = sort_fragments(frag_mol)
        row_list.append([smiles]+[Chem.MolToSmiles(x) for x in pair_list]+[name, pIC50])
row_df = pd.DataFrame(row_list,columns=["SMILES","Core","R_group","Name","pIC50"])
row_df
# Out:
#                                                  SMILES  \
# 0                     O=c1[nH]c2ccc(-c3cccc(Cl)c3)cc2s1
# 1                     O=c1[nH]c2ccc(-c3cccc(Cl)c3)cc2s1
# 2     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...
# 3     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...
# 4     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1Cc1...
# ...                                                 ...
# 3083            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3084            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3085            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3086            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
# 3087            Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1Cl
#
#                                                   Core  \
# 0                            O=c1[nH]c2ccc([*:1])cc2s1
# 1                 O=c1[nH]c2ccc(-c3cccc([*:1])c3)cc2s1
# 2                   O=c1[nH]c2ccc([*:1])cc2n1Cc1ccccc1
# 3        O=c1[nH]c2ccc(-c3cccc([*:1])c3)cc2n1Cc1ccccc1
# 4     O=c1[nH]c2ccc(-c3cccc([N+](=O)[O-])c3)cc2n1[*:1]
# ...                                                ...
# 3083                          Cc1c(N[*:1])ccc(C#N)c1Cl
# 3084        Cc1c(N[C@@H]2CCC[C@]2(O)[*:1])ccc(C#N)c1Cl
# 3085        Cc1c(N[C@@H]2CCC[C@]2(C)[*:1])ccc(C#N)c1Cl
# 3086         Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc([*:1])c1Cl
# 3087        Cc1c(N[C@@H]2CCC[C@@]2(C)O)ccc(C#N)c1[*:1]
#
#                           R_group           Name  pIC50
# 0               Clc1cccc([*:1])c1    CHEMBL94053   6.90
# 1                         Cl[*:1]    CHEMBL94053   6.90
# 2     O=[N+]([O-])c1cccc([*:1])c1   CHEMBL327409   6.15
# 3               O=[N+]([O-])[*:1]   CHEMBL327409   6.15
# 4                c1ccc(C[*:1])cc1   CHEMBL327409   6.15
# ...                           ...            ...    ...
# 3083     C[C@@]1(O)CCC[C@H]1[*:1]  CHEMBL3764185   6.06
# 3084                       C[*:1]  CHEMBL3764185   6.06
# 3085                       O[*:1]  CHEMBL3764185   6.06
# 3086                     N#C[*:1]  CHEMBL3764185   6.06
# 3087                      Cl[*:1]  CHEMBL3764185   6.06
#
# [3088 rows x 5 columns]

# %% [markdown]
# ### View Scaffolds
# Put the scaffolds into a dataframe

# %%
scaffold_df = row_df.Core.value_counts().to_frame().reset_index()
scaffold_df.columns = ["SMILES","Count"]
scaffold_df['mol'] = scaffold_df.SMILES.apply(Chem.MolFromSmiles)
_ = scaffold_df.mol.apply(Compute2DCoords)

# %% [markdown]
# Display the scaffolds

# %%
mols2grid.display(scaffold_df.head(20),subset=["img","Count"],mol_col="mol",
                  use_coords=True,prerender=True,template="static")
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: break-word;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: visible;
#     white-space: normal;
#     text-overflow: clip;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             /* Note: #mols2grid is the table element */
# #mols2grid {
#     border-collapse: collapse;
#     border-spacing: 0px;
#     /* Compensate for gap so table stays aligned with content above */
#     margin: 0px;
# }
# #mols2grid, tr, td {
#     border: none;
# }
# #mols2grid tr {
#     page-break-inside: avoid !important;
# }
#
# /* Cell */
# #mols2grid td {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 130px;
#     width: 130px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12px;
#     margin: 0;
#     padding: 10px;
#     position: relative;
# }
#
# /* Call focus state */
# #mols2grid td:focus-within,
# #mols2grid td:focus {
#     outline: solid 2px #555;
#     border-color: transparent;
# }
#
# /* ID */
# #mols2grid .data-mols2grid-id {
#     position: absolute;
#     top: 0;
#     left: 0;
#     padding: 5px;
# }
#
# /* Tooltip margin */
# /* Adjusted so it plays well with the extruded outline */
# .popover[x-placement] {
#     margin: 1px 2px 2px 1px;
# }
#
#
# #mols2grid td div img {
#     max-width: px;
#     width: px;
#     height: auto;
#     padding: 0;
# }
#
#             /* Custom CSS */
#
#         &lt;/style&gt;
#         &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#     // Set iframe height to fit content.
#     function fitIframe(iframe) {
#         // Ignore when there&#x27;s no iframe
#         if (!iframe) return
#
#         // Only fit height when no specific height was given.
#         if (iframe.getAttribute(&#x27;height&#x27;)) return;
#
#         // Initial fit + refit whenever the window width changes.
#         _fit()
#         $(window).on(&#x27;resize&#x27;, function() {
#             if (window.innerWidth != window.prevInnerWidth) {
#                 window.prevInnerWidth = window.innerWidth
#                 _fit();
#             }
#         })
#
#         // Fit iframe height to content height.
#         function _fit() {
#             var height = iframe.contentDocument.body.scrollHeight + 18 + &#x27;px&#x27;;
#             iframe.style.height = height;
#         }
#     }
# &lt;/script&gt;
#
# &lt;!-- prettier-ignore --&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#
#         &lt;!-- Custom header --&gt;
#
#
#
#
#
#     &lt;/head&gt;
#     &lt;body class=&quot;m2g-inside-iframe&quot;&gt;
#
#
#         &lt;table id=&quot;mols2grid&quot;&gt;
#             &lt;tbody&gt;
#                 &lt;tr class=&quot;row-0&quot;&gt;
# &lt;td class=&quot;col-0 m2g-tooltip&quot; tabindex=&quot;0&quot; data-toggle=&quot;popover&quot; data-content=&quot;&quot;&gt;
# &lt;div class=&quot;m2g-cell-0&quot;&gt;
# &lt;div class=&quot;data copy-me data-img&quot;&gt;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;
# &lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;
#               xmlns=&#x27;http://www.w3.org/2000/svg&#x27;
#                       xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;
#                       xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;
#                   xml:space=&#x27;preserve&#x27;
# width=&#x27;130px&#x27; height=&#x27;90px&#x27; viewBox=&#x27;0 0 130 90&#x27;&gt;
# &lt;!-- END OF HEADER --&gt;
# &lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;130.0&#x27; height=&#x27;90.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 46.8,69.6 L 41.2,54.8&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 41.2,54.8 L 25.7,52.3&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 40.3,52.3 L 27.4,50.2&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 25.7,52.3 L 20.1,37.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-3 atom-3 atom-4&#x27; d=&#x27;M 20.1,37.6 L 6.5,45.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-4 atom-3 atom-5&#x27; d=&#x27;M 20.1,37.6 L 9.7,25.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-5 atom-3 atom-6&#x27; d=&#x27;M 20.1,37.6 L 23.9,32.8&#x27; style=&#x27;fi

# %% [markdown]
# ### View Matched Molecular Series
# Set **idx** to the index from the scaffold table above to display molecules from that series
# Set **clear_matches** to **False** to highlight the scaffold in the table below

# %%
idx = 2
clear_matches = False
scaffold_smi = scaffold_df.SMILES.values[idx]
scaffold_mol = scaffold_df.mol.values[idx]
scaffold_mol = cleanup_fragment(scaffold_mol)[0]
current_df = row_df.query("Core == @scaffold_smi").sort_values("pIC50",ascending=False).copy()
current_df['mol'] = current_df.SMILES.apply(Chem.MolFromSmiles)
for mol in current_df.mol.values:
    AlignMolToTemplate2D(mol, scaffold_mol)
    if clear_matches:
        mol.__sssAtoms = []
mols2grid.display(current_df,subset=["img","pIC50"],mol_col="mol",use_coords=True,prerender=True,template="static")
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: break-word;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: visible;
#     white-space: normal;
#     text-overflow: clip;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             /* Note: #mols2grid is the table element */
# #mols2grid {
#     border-collapse: collapse;
#     border-spacing: 0px;
#     /* Compensate for gap so table stays aligned with content above */
#     margin: 0px;
# }
# #mols2grid, tr, td {
#     border: none;
# }
# #mols2grid tr {
#     page-break-inside: avoid !important;
# }
#
# /* Cell */
# #mols2grid td {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 130px;
#     width: 130px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12px;
#     margin: 0;
#     padding: 10px;
#     position: relative;
# }
#
# /* Call focus state */
# #mols2grid td:focus-within,
# #mols2grid td:focus {
#     outline: solid 2px #555;
#     border-color: transparent;
# }
#
# /* ID */
# #mols2grid .data-mols2grid-id {
#     position: absolute;
#     top: 0;
#     left: 0;
#     padding: 5px;
# }
#
# /* Tooltip margin */
# /* Adjusted so it plays well with the extruded outline */
# .popover[x-placement] {
#     margin: 1px 2px 2px 1px;
# }
#
#
# #mols2grid td div img {
#     max-width: px;
#     width: px;
#     height: auto;
#     padding: 0;
# }
#
#             /* Custom CSS */
#
#         &lt;/style&gt;
#         &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#     // Set iframe height to fit content.
#     function fitIframe(iframe) {
#         // Ignore when there&#x27;s no iframe
#         if (!iframe) return
#
#         // Only fit height when no specific height was given.
#         if (iframe.getAttribute(&#x27;height&#x27;)) return;
#
#         // Initial fit + refit whenever the window width changes.
#         _fit()
#         $(window).on(&#x27;resize&#x27;, function() {
#             if (window.innerWidth != window.prevInnerWidth) {
#                 window.prevInnerWidth = window.innerWidth
#                 _fit();
#             }
#         })
#
#         // Fit iframe height to content height.
#         function _fit() {
#             var height = iframe.contentDocument.body.scrollHeight + 18 + &#x27;px&#x27;;
#             iframe.style.height = height;
#         }
#     }
# &lt;/script&gt;
#
# &lt;!-- prettier-ignore --&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#
#         &lt;!-- Custom header --&gt;
#
#
#
#
#
#     &lt;/head&gt;
#     &lt;body class=&quot;m2g-inside-iframe&quot;&gt;
#
#
#         &lt;table id=&quot;mols2grid&quot;&gt;
#             &lt;tbody&gt;
#                 &lt;tr class=&quot;row-0&quot;&gt;
# &lt;td class=&quot;col-0 m2g-tooltip&quot; tabindex=&quot;0&quot; data-toggle=&quot;popover&quot; data-content=&quot;&quot;&gt;
# &lt;div class=&quot;m2g-cell-0&quot;&gt;
# &lt;div class=&quot;data copy-me data-img&quot;&gt;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;
# &lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;
#               xmlns=&#x27;http://www.w3.org/2000/svg&#x27;
#                       xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;
#                       xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;
#                   xml:space=&#x27;preserve&#x27;
# width=&#x27;130px&#x27; height=&#x27;90px&#x27; viewBox=&#x27;0 0 130 90&#x27;&gt;
# &lt;!-- END OF HEADER --&gt;
# &lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;130.0&#x27; height=&#x27;90.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 36.8,23.1 L 40.7,23.9 L 38.2,34.8 L 36.0,35.5 L 34.4,34.0 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 34.4,34.0 L 36.0,35.5 L 35.5,37.7 L 25.9,40.7 L 22.6,37.6 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-20 atom-1 atom-20&#x27; d=&#x27;M 38.2,34.8 L 45.6,41.6 L 45.1,43.9 L 42.9,44.5 L 35.5,37.7 L 36.0,35.5 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 22.6,37.6 L 25.9,40.7 L 23.7,50.5 L 21.6,51.2 L 20.2,48.5 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-3 atom-3 atom-4&#x27; d=&#x27;M 21.6,51.2 L 22.0,54.2 L 16.6,62.6 L 13.3,60.5 L 18.6,52.1 Z&#x27; style=&#x27;fill:#FF7F7F;fill-rule:evenodd;fill-opacity:1;stroke:#FF7F7F;stroke-width:0.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;&#x27; /&gt;
# &lt;path class=&#x27;bond-4 at
